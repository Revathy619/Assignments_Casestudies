# %% [markdown]
# # Case Study on Correlation and Regression
# A textile company regularly spent money on five advertising companies for their
# ads.
#
# 1. First of all, check whether there is any relationship between the amount
# spent for advertising through five different companies and profit
# generated.
#
# 2. Build a regression model to predict the profit from the given data and
# comment your findings on it.
#
# 3. Predict the profit generated by the company, if they wish to spend the
# following amount for advertisement.
#
# Add1(in Thousands) 290
# Add2(in Thousands) 312
# Add3(in Thousands) 309
# Add4(in Thousands) 298
# Add5(in Thousands) 320

# %%
#Importing the necessary libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing the required dataset
data = pd.read_csv("F:\\pythonprogramming\\Add_sales_data_2018.csv")

# %%
#Printing the dataset
data
# Out:
#            Date  Add1(in Thousands)  Add2(in Thousands)  Add3(in Thousands)  \
# 0    2018-10-08              208.00              222.25              206.85
# 1    2018-10-05              217.00              218.60              205.90
# 2    2018-10-04              223.50              227.80              216.15
# 3    2018-10-03              230.00              237.50              225.75
# 4    2018-10-01              234.55              234.60              221.05
# ..          ...                 ...                 ...                 ...
# 200  2017-12-14              288.00              288.25              279.20
# 201  2017-12-13              290.00              292.50              282.20
# 202  2017-12-12              298.60              298.60              286.65
# 203  2017-12-11              290.00              299.55              285.90
# 204  2017-12-08              287.55              289.90              285.05
#
# ...

# %%
# To verify null data items
data.isnull().sum()
# Out:
# Date                    0
# Add1(in Thousands)      0
# Add2(in Thousands)      0
# Add3(in Thousands)      0
# Add4(in Thousands)      0
# Add5(in Thousands)      0
# Profit(in Thousands)    0
# dtype: int64

# %%
data['Profit(in Thousands)'].unique()
# Out:
# array([4093.065, 4042.448, 4213.819, 4391.665, 4350.683, 4404.686,
#        4418.709, 4470.775, 4425.005, 4446.441, 4411.775, 4435.571,
#        4464.11 , 4434.805, 4379.901, 4152.066, 4175.677, 4326.782,
#        4190.965, 4193.095, 4178.008, 4390.996, 4523.704, 4465.95 ,
#        4435.174, 4436.321, 4451.999, 4453.773, 4416.136, 4482.183,
#        4598.292, 4617.695, 4566.31 , 4513.6  , 4461.325, 4419.421,
#        4435.816, 4480.363, 4486.38 , 4506.279, 4486.996, 4453.205,
#        4432.864, 4672.391, 4648.627, 4606.34 , 4558.651, 4519.061,
#        4599.49 , 4643.716, 4548.11 , 4477.226, 4494.144, 4605.783,
#        4671.113, 4760.877, 4947.72 , 5071.736, 5133.766, 5190.814,
#        5145.131, 5088.455, 5234.487, 5250.775, 5239.06 , 5075.858,
#        5038.222, 5001.615, 5004.282, 5030.451, 4977.891, 4916.064,
#        4890.723, 4936.12 , 5113.337, 5163.693, 5225.14 , 5187.445,
#        5057.155, 5013.207, 5043.705, 5027.633, 5034.726, 4980.446,
# ...

# %%
data.describe()
# Out:
#        Add1(in Thousands)  Add2(in Thousands)  Add3(in Thousands)  \
# count          205.000000          205.000000          205.000000
# mean           267.577561          271.722439          262.990732
# std             26.219588           25.914939           26.126704
# min            208.000000          218.600000          205.900000
# 25%            244.000000          248.500000          240.300000
# 50%            269.700000          274.200000          263.250000
# 75%            284.400000          288.800000          280.900000
# max            327.700000          328.750000          321.650000
#
#        Add4(in Thousands)  Add5(in Thousands)  Profit(in Thousands)
# count          205.000000          205.000000            205.000000
# mean           267.223902          267.152683           5059.630234
# std             26.238832           26.215360            486.910414
# min            210.250000          209.200000           4042.448000
# ...

# %% [markdown]
# # 1.First of all, check whether there is any relationship between the amount spent for advertising through five different companies and profit generated

# %%
#Correlation Analysis
data.corr()
# Out:
#                       Add1(in Thousands)  Add2(in Thousands)  \
# Add1(in Thousands)              1.000000            0.990976
# Add2(in Thousands)              0.990976            1.000000
# Add3(in Thousands)              0.986274            0.987990
# Add4(in Thousands)              0.976365            0.989921
# Add5(in Thousands)              0.976716            0.990285
# Profit(in Thousands)            0.991975            0.999145
#
#                       Add3(in Thousands)  Add4(in Thousands)  \
# Add1(in Thousands)              0.986274            0.976365
# Add2(in Thousands)              0.987990            0.989921
# Add3(in Thousands)              1.000000            0.991343
# Add4(in Thousands)              0.991343            1.000000
# Add5(in Thousands)              0.991908            0.999699
# Profit(in Thousands)            0.993389            0.993346
#
#                       Add5(in Thousands)  Profit(in Thousands)
# ...

# %%
 #Plotting a heatmap to show coorelation
corrmatrix = data.corr()
plt.subplots(figsize=(10,5))
sns.heatmap(corrmatrix,vmin=-1,vmax=1,annot=True,linewidths=0.2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Insight: All the companies have very high positive correlation between amount spend and profit generated, ie, if amount spend on advertisements increases profit also increases.

# %% [markdown]
# # 2.Build a regression model to predict the profit from the given data and comment your findings on it

# %%
data.columns
# Out:
# Index(['Date', 'Add1(in Thousands)', 'Add2(in Thousands)',
#        'Add3(in Thousands)', 'Add4(in Thousands)', 'Add5(in Thousands)',
#        'Profit(in Thousands)'],
#       dtype='object')

# %%
#Building a model with profit as Target and five Adds as features
data6= data.drop(['Date'], axis=1)
y= data6['Profit(in Thousands)']
x=data6.drop(['Profit(in Thousands)'],axis=1)
x.shape
# Out:
# (205, 5)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,random_state=42,test_size=0.25)
from sklearn import linear_model
lr = linear_model.LinearRegression()
model= lr.fit(x_train,y_train)
predictions = model.predict(x_test) 
print(y_test)
print(predictions)
# Out:
# 15     4152.066
# 9      4446.441
# 100    5131.898
# 132    4907.560
# 68     5004.282
# 95     4623.793
# 159    5384.175
# 162    5328.025
# 147    5175.051
# 182    5956.323
# 191    5780.799
# 164    4997.719
# 65     5075.858
# 175    5784.540
# 73     4936.120
# 152    5065.652
# 18     4190.965
# 82     5034.726
# 86     5015.536
# 143    5134.657
# 60     5145.131
# 101    5421.940
# 98     4569.293
# 30     4598.292
# 25     4436.321
# 16     4175.677
# 168    5616.791
# 195    5667.250
# 97     4648.834
# 194    5717.838
# 67     5001.615
# 120    5182.368
# 154    5017.503
# 202    5545.013
# 79     5013.207
# 69     5030.451
# 145    5108.626
# 55     4760.877
# 45     4606.340
# 84     4925.861
# 146    5250.788
# 66     5038.222
# 111    5491.792
# 153    5019.997
# 96     4647.356
# 38     4486.380
# 24     4435.174
# 139    5300.437
# 112    5425.190
# 29     4482.183
# 19     4193.095
# 178    6062.457
# Name: Profit(in Thousands), dtype: float64
# ...

# %%
#To find the efficiency of our regression model by finding MSE
from sklearn.metrics import mean_squared_error
print("MSE is :",mean_squared_error(y_test,predictions))
# Out:
# MSE is : 8.11273293080854e-25

# %% [markdown]
#  MSE value is 8.11273293080854e-25 which is very low, so that our model is perfect

# %%
#To find the efficiency of our regression model by finding R^2 Value
from sklearn.metrics import r2_score
r2=r2_score(y_test,predictions)
print("R^2 value is:",r2)
# Out:
# R^2 value is: 1.0

# %% [markdown]
# Also, R squared value of 1.0 indicates the model is perfect.

# %%
corr = x.corr()
corr
# Out:
#                     Add1(in Thousands)  Add2(in Thousands)  \
# Add1(in Thousands)            1.000000            0.990976
# Add2(in Thousands)            0.990976            1.000000
# Add3(in Thousands)            0.986274            0.987990
# Add4(in Thousands)            0.976365            0.989921
# Add5(in Thousands)            0.976716            0.990285
#
#                     Add3(in Thousands)  Add4(in Thousands)  Add5(in Thousands)
# Add1(in Thousands)            0.986274            0.976365            0.976716
# Add2(in Thousands)            0.987990            0.989921            0.990285
# Add3(in Thousands)            1.000000            0.991343            0.991908
# Add4(in Thousands)            0.991343            1.000000            0.999699
# Add5(in Thousands)            0.991908            0.999699            1.000000

# %% [markdown]
# # 3.Predict the profit generated by the company, if they wish to spend the following amount for advertisement.

# %%
#Checking the improvement of our model
make_pred=[[290,312,309,298,320]]
model.predict(make_pred).item()
# Out:
# 5820.0599999999995

# %% [markdown]
# CONCLUSION: If the company spend the following amounts for advertisement Add1(in Thousands) 290 Add2(in Thousands) 312 Add3(in Thousands) 309 Add4(in Thousands) 298 Add5(in Thousands) 320, the profit generated will be 5820.0599999999995
